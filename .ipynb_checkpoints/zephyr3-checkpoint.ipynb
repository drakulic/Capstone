# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics import regressionplots as smg
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as scs
import plotly.plotly as py
from plotly.graph_objs import *
from sklearn.preprocessing import scale, StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import cross_val_predict, cross_val_score, train_test_split
from sklearn import linear_model, svm, metrics
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import f_regression, chi2
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %%
# %matplotlib inline

# %%
df =pd.read_excel('zephyr_no_outl.xlsx')

# %%
df.head(3)
# Out:
#             address           district  bedroom  bath  parking   sqft  \
# 0  2701 Broadway St  Pacific Heights          7  7.00        2  16400
# 1      2250 Vallejo  Pacific Heights          7  7.00        2   9095
# 2   2950 Vallejo St  Pacific Heights          8  5.75        2   6244
#
#    dollar_sqft       sold  home_own_ass  day_on_market  list_price  \
# 0  1890.243902  05/15/15            0.0            100    39000000
# 1  2396.921385  10/14/16            0.0            213    28000000
# 2  2684.176810  06/15/15            0.0              0    16995000
#
#    sale_price  sale_to_list_ratio  single_f_h  condo  dist_no
# 0    31000000           79.487179           1      0        7
# 1    21800000           77.857143           1      0        7
# 2    16760000           98.617240           1      0        7

# %%
df.count()
# Out:
# address               4339
# district              4339
# bedroom               4339
# bath                  4339
# parking               4339
# sqft                  4339
# dollar_sqft           4339
# sold                  4339
# home_own_ass          4339
# day_on_market         4339
# list_price            4339
# sale_price            4339
# sale_to_list_ratio    4339
# single_f_h            4339
# condo                 4339
# dist_no               4339
# dtype: int64

# %%
df.describe()
# Out:
#            bedroom         bath      parking          sqft  dollar_sqft  \
# count  4339.000000  4339.000000  4339.000000   4339.000000  4339.000000
# mean      2.333487     1.891219     1.231851   1498.730122   923.312493
# std       1.188779     1.008725     0.709996    991.933981   408.113680
# min       0.000000     1.000000     0.000000    210.000000   125.000000
# 25%       2.000000     1.000000     1.000000    949.500000   621.381479
# 50%       2.000000     2.000000     1.000000   1249.000000   889.884763
# 75%       3.000000     2.000000     2.000000   1728.500000  1133.058558
# max       9.000000     8.000000     7.000000  16400.000000  5597.014925
#
#        home_own_ass  day_on_market    list_price    sale_price  \
# count   4339.000000    4339.000000  4.339000e+03  4.339000e+03
# mean     398.147944      36.997004  1.431594e+06  1.471454e+06
# std      740.422013      42.229540  1.781861e+06  1.652144e+06
# min        0.000000       0.000000  1.395000e+05  1.399000e+05
# 25%        0.000000      13.000000  6.480000e+05  6.900000e+05
# 50%      278.150000      25.000000  8.490000e+05  9.010000e+05
# 75%      584.730000      47.000000  1.450000e+06  1.500000e+06
# max    31356.770000     609.000000  3.900000e+07  3.100000e+07
#
#        sale_to_list_ratio   single_f_h        condo      dist_no
# count         4339.000000  4339.000000  4339.000000  4339.000000
# mean           106.524001     0.421065     0.578935     8.493432
# std             12.550323     0.493787     0.493787     1.245792
# min             57.368421     0.000000     0.000000     7.000000
# 25%            100.000000     0.000000     0.000000     7.000000
# 50%            104.838710     0.000000     1.000000     8.000000
# 75%            113.463053     1.000000     1.000000    10.000000
# max            192.093023     1.000000     1.000000    10.000000

# %%
print df.columns
# Out:
# Index([u'address', u'district', u'bedroom', u'bath', u'parking', u'sqft',
#        u'dollar_sqft', u'sold', u'home_own_ass', u'day_on_market',
#        u'list_price', u'sale_price', u'sale_to_list_ratio', u'single_f_h',
#        u'condo', u'dist_no'],
#       dtype='object')

# %%
sold_dt = pd.to_datetime(df.sold, infer_datetime_format=True)

# %%
sold_dt.head(3)
# Out:
# 0   2015-05-15
# 1   2016-10-14
# 2   2015-06-15
# Name: sold, dtype: datetime64[ns]

# %%
df.sold = sold_dt

# %%
df.sold.head(3)
# Out:
# 0   2015-05-15
# 1   2016-10-14
# 2   2015-06-15
# Name: sold, dtype: datetime64[ns]

# %%
df.head(3)
# Out:
#             address           district  bedroom  bath  parking   sqft  \
# 0  2701 Broadway St  Pacific Heights          7  7.00        2  16400
# 1      2250 Vallejo  Pacific Heights          7  7.00        2   9095
# 2   2950 Vallejo St  Pacific Heights          8  5.75        2   6244
#
#    dollar_sqft       sold  home_own_ass  day_on_market  list_price  \
# 0  1890.243902 2015-05-15           0.0            100    39000000
# 1  2396.921385 2016-10-14           0.0            213    28000000
# 2  2684.176810 2015-06-15           0.0              0    16995000
#
#    sale_price  sale_to_list_ratio  single_f_h  condo  dist_no
# 0    31000000           79.487179           1      0        7
# 1    21800000           77.857143           1      0        7
# 2    16760000           98.617240           1      0        7

# %%
fig = plt.figure(figsize=(25,15))
plt.plot(df.sort_values('sold').sold, df.sort_values('sold').sale_price)
fig.suptitle('sale price over time', fontsize=20)
plt.xlabel('Sold', fontsize=20)
plt.ylabel('sale price', fontsize=20)
plt.show()

# %%
sp_log = np.log10(df.sort_values('sold').sale_price)

# %%
sp_log.head(3)
# Out:
# 1620    6.053078
# 3774    5.774517
# 3697    5.785330
# Name: sale_price, dtype: float64

# %%
fig = plt.figure(figsize=(25,15))
plt.plot(df.sort_values('sold').sold, sp_log)
fig.suptitle('log10 of sale price over time', fontsize=20)
plt.xlabel('Sold', fontsize=20)
plt.ylabel('log10 of sale price', fontsize=20)
plt.show()

# %%
format = lambda x: x.year
df.sold_year = df.sold.map(format)
df['sold_year'] = pd.Series(df.sold_year, index=df.index)

# %%
df.sold_year.head(3)
# Out:
# 0    2015
# 1    2016
# 2    2015
# Name: sold, dtype: int64

# %%
format2 = lambda x: x.month
df.sold_month = df.sold.map(format2)
df['sold_month'] = pd.Series(df.sold_month, index=df.index)

# %%
df.sold_month.head(3)
# Out:
# 0     5
# 1    10
# 2     6
# Name: sold, dtype: int64

# %%
df.head(3)
# Out:
#             address           district  bedroom  bath  parking   sqft  \
# 0  2701 Broadway St  Pacific Heights          7  7.00        2  16400
# 1      2250 Vallejo  Pacific Heights          7  7.00        2   9095
# 2   2950 Vallejo St  Pacific Heights          8  5.75        2   6244
#
#    dollar_sqft       sold  home_own_ass  day_on_market  list_price  \
# 0  1890.243902 2015-05-15           0.0            100    39000000
# 1  2396.921385 2016-10-14           0.0            213    28000000
# 2  2684.176810 2015-06-15           0.0              0    16995000
#
#    sale_price  sale_to_list_ratio  single_f_h  condo  dist_no  sold_year  \
# 0    31000000           79.487179           1      0        7       2015
# 1    21800000           77.857143           1      0        7       2016
# 2    16760000           98.617240           1      0        7       2015
#
#    sold_month
# 0           5
# 1          10
# 2           6

# %%
print '\nmodel with year month columns, no log10: \n'
model_y_m = smf.ols(formula='sale_price ~ district + bedroom + bath + parking + sqft + home_own_ass + day_on_market + list_price + single_f_h + condo + dist_no + sold_year + sold_month', data=df)
linreg_no_log = model_y_m.fit()
print linreg_no_log.summary()
# Out:
# model with year month columns, no log10:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             sale_price   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     5900.
# Date:                Mon, 28 Nov 2016   Prob (F-statistic):               0.00
# Time:                        01:57:41   Log-Likelihood:                -59963.
# No. Observations:                4339   AIC:                         1.200e+05
# Df Residuals:                    4305   BIC:                         1.202e+05
# Df Model:                          33
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                   -9.764e+06   2.97e+06     -3.293      0.001     -1.56e+07 -3.95e+06
# district[T.u'Bayview\xa0\xa0']               2958.5245   4.11e+04      0.072      0.943     -7.76e+04  8.35e+04
# district[T.u'Candlestick Point\xa0\xa0']     8.151e+04   5.25e+04      1.553      0.121     -2.14e+04  1.84e+05
# district[T.u'Cow Hollow\xa0\xa0']           -4.258e+06   1.29e+06     -3.301      0.001     -6.79e+06 -1.73e+06
# district[T.u'Crocker Amazon\xa0\xa0']       -1847.5796   4.31e+04     -0.043      0.966     -8.63e+04  8.26e+04
# district[T.u'Downtown\xa0\xa0']             -2.868e+06   8.59e+05     -3.338      0.001     -4.55e+06 -1.18e+06
# district[T.u'Excelsior\xa0\xa0']            -1393.6589   4.14e+04     -0.034      0.973     -8.26e+04  7.98e+04
# district[T.u'Financial District\xa0\xa0']   -2.844e+06   8.59e+05     -3.309      0.001     -4.53e+06 -1.16e+06
# district[T.u'Hunters Point\xa0\xa0']         1.043e+05   6.37e+04      1.637      0.102     -2.06e+04  2.29e+05
# district[T.u'Little Hollywood\xa0\xa0']      1.044e+04    6.8e+04      0.153      0.878     -1.23e+05  1.44e+05
# district[T.u'Marina\xa0\xa0']               -4.278e+06   1.29e+06     -3.318      0.001     -6.81e+06 -1.75e+06
# district[T.u'Mission Terrace\xa0\xa0']       4.448e+04   4.39e+04      1.012      0.312     -4.17e+04  1.31e+05
# district[T.u'Nob Hill\xa0\xa0']             -2.813e+06    8.6e+05     -3.271      0.001      -4.5e+06 -1.13e+06
# district[T.u'North Beach\xa0\xa0']          -2.853e+06   8.61e+05     -3.313      0.001     -4.54e+06 -1.16e+06
# district[T.u'North Waterfront\xa0\xa0']     -2.884e+06    8.6e+05     -3.355      0.001     -4.57e+06  -1.2e+06
# district[T.u'Outer Mission\xa0\xa0']        -7504.2656   4.39e+04     -0.171      0.864     -9.37e+04  7.87e+04
# district[T.u'Pacific Heights\xa0\xa0']      -4.251e+06   1.29e+06     -3.297      0.001     -6.78e+06 -1.72e+06
# district[T.u'Portola\xa0\xa0']              -6082.6649   4.21e+04     -0.144      0.885     -8.87e+04  7.65e+04
# district[T.u'Presidio Heights\xa0\xa0']     -4.125e+06   1.29e+06     -3.200      0.001     -6.65e+06  -1.6e+06
# district[T.u'Russian Hill\xa0\xa0']         -2.758e+06    8.6e+05     -3.209      0.001     -4.44e+06 -1.07e+06
# district[T.u'Silver Terrace\xa0\xa0']       -1.898e+04   4.51e+04     -0.421      0.674     -1.07e+05  6.94e+04
# district[T.u'Telegraph Hill\xa0\xa0']       -2.812e+06    8.6e+05     -3.269      0.001      -4.5e+06 -1.13e+06
# district[T.u'Van Ness/Civic Cente\xa0\xa0']  -2.86e+06    8.6e+05     -3.327      0.001     -4.55e+06 -1.17e+06
# district[T.u'Visitacion Valley\xa0\xa0']    -4.225e+04   4.29e+04     -0.984      0.325     -1.26e+05   4.2e+04
# bedroom                                      7892.5781   6084.141      1.297      0.195     -4035.473  1.98e+04
# bath                                         5.177e+04   7409.511      6.987      0.000      3.72e+04  6.63e+04
# parking                                       2.51e+04   6245.334      4.019      0.000      1.29e+04  3.73e+04
# sqft                                           26.5300      9.850      2.693      0.007         7.220    45.840
# home_own_ass                                   21.6918      5.989      3.622      0.000         9.950    33.433
# day_on_market                               -2190.9494     90.510    -24.207      0.000     -2368.395 -2013.504
# list_price                                      0.8442      0.005    187.443      0.000         0.835     0.853
# single_f_h                                  -4.799e+06   1.48e+06     -3.237      0.001     -7.71e+06 -1.89e+06
# condo                                       -4.964e+06   1.48e+06     -3.347      0.001     -7.87e+06 -2.06e+06
# dist_no                                     -1.516e+06    4.3e+05     -3.526      0.000     -2.36e+06 -6.73e+05
# sold_year                                     1.48e+04   4340.248      3.411      0.001      6293.682  2.33e+04
# sold_month                                  -1356.2962   1164.406     -1.165      0.244     -3639.132   926.540
# ==============================================================================
# Omnibus:                     1871.128   Durbin-Watson:                   1.708
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           851766.154
# Skew:                           0.697   Prob(JB):                         0.00
# Kurtosis:                      71.625   Cond. No.                     1.28e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.38e-16. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
df_sold = df.sort_values('sold')
df_sold = df_sold.set_index('sold')

# %%
df_sold.head(3)
# Out:
#                          address              district  bedroom  bath  \
# sold
# 2013-11-12      20 Vandewater St         North Beach          2   2.0
# 2013-11-12  946 Stockton St #14A  Financial District          2   1.5
# 2013-11-12         930 Pine #211            Downtown          1   1.0
#
#             parking  sqft  dollar_sqft  home_own_ass  day_on_market  \
# sold
# 2013-11-12        1  1456   776.098901        565.00             38
# 2013-11-12        0   744   799.731183        556.00              8
# 2013-11-12        1   700   871.428571        511.14             35
#
#             list_price  sale_price  sale_to_list_ratio  single_f_h  condo  \
# sold
# 2013-11-12     1195000     1130000           94.560669           0      1
# 2013-11-12      500000      595000          119.000000           0      1
# 2013-11-12      599000      610000          101.836394           0      1
#
#             dist_no  sold_year  sold_month
# sold
# 2013-11-12        8       2013          11
# 2013-11-12        8       2013          11
# 2013-11-12        8       2013          11

# %%
df_sold.index[0:20]
# Out:
# DatetimeIndex(['2013-11-12', '2013-11-12', '2013-11-12', '2013-11-13',
#                '2013-11-13', '2013-11-13', '2013-11-13', '2013-11-13',
#                '2013-11-13', '2013-11-13', '2013-11-13', '2013-11-13',
#                '2013-11-13', '2013-11-13', '2013-11-13', '2013-11-14',
#                '2013-11-14', '2013-11-14', '2013-11-14', '2013-11-14'],
#               dtype='datetime64[ns]', name=u'sold', freq=None)

# %%
fig = plt.figure(figsize=(25,15))
plt.plot(df_sold[['list_price']], color = 'green')
plt.plot(df_sold[['sale_price']], color = 'red')
plt.xlabel('Sold', fontsize=20)
fig.suptitle('sale and list price over time', fontsize=20)
plt.ylabel('sale red,     list green', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
plt.plot(df_sold[['list_price']], color = 'blue')
plt.plot(df_sold[['sale_price']], color = 'red')
plt.xlabel('Sold', fontsize=20)
fig.suptitle('sale and list price over time', fontsize=20)
plt.ylabel('sale red,     list blue', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
plt.plot(np.log10(df_sold.sale_price), color='red')
plt.plot(np.log10(df_sold.list_price), color = 'blue')
plt.xlabel('Sold', fontsize=20)
fig.suptitle('log10 of sale and list price over time', fontsize=20)
plt.ylabel('sale red,     list blue', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
plt.scatter(df_sold.index, np.log10(df_sold.sale_price))
fig.suptitle('sale price over time', fontsize=20)
plt.ylabel('log10 of sale price', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
plt.scatter(df_sold.index, np.log10(df_sold.list_price))
fig.suptitle('list price over time', fontsize=20)
plt.ylabel('log10 of list price', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
np.log10(df_sold.list_price).plot()
fig.suptitle('log10 of list price over time', fontsize=20)
plt.ylabel('log10 of list price', fontsize=20)
plt.show()

# %%
model_sold_list = smf.ols(formula='np.log10(sale_price) ~ district + bedroom + bath + parking + sqft + home_own_ass + day_on_market + np.log10(list_price) + single_f_h + condo + dist_no + sold_year + sold_month', data=df_sold)
linreg3 = model_sold_list.fit()
print '\nmodel with log10 list price: ', linreg3.summary()
# Out:
# model with log10 list price:                               OLS Regression Results
# ================================================================================
# Dep. Variable:     np.log10(sale_price)   R-squared:                       0.980
# Model:                              OLS   Adj. R-squared:                  0.980
# Method:                   Least Squares   F-statistic:                     6299.
# Date:                  Mon, 28 Nov 2016   Prob (F-statistic):               0.00
# Time:                          01:58:20   Log-Likelihood:                 7568.8
# No. Observations:                  4339   AIC:                        -1.507e+04
# Df Residuals:                      4305   BIC:                        -1.485e+04
# Df Model:                            33
# Covariance Type:              nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                      -0.6835      0.529     -1.292      0.197        -1.721     0.354
# district[T.u'Bayview\xa0\xa0']                  0.0003      0.007      0.038      0.969        -0.014     0.014
# district[T.u'Candlestick Point\xa0\xa0']       -0.0050      0.009     -0.547      0.584        -0.023     0.013
# district[T.u'Cow Hollow\xa0\xa0']              -0.2982      0.230     -1.296      0.195        -0.749     0.153
# district[T.u'Crocker Amazon\xa0\xa0']           0.0081      0.008      1.075      0.283        -0.007     0.023
# district[T.u'Downtown\xa0\xa0']                -0.2104      0.153     -1.371      0.170        -0.511     0.090
# district[T.u'Excelsior\xa0\xa0']                0.0117      0.007      1.614      0.107        -0.003     0.026
# district[T.u'Financial District\xa0\xa0']      -0.2008      0.153     -1.310      0.190        -0.501     0.100
# district[T.u'Hunters Point\xa0\xa0']           -0.0072      0.011     -0.648      0.517        -0.029     0.015
# district[T.u'Little Hollywood\xa0\xa0']        -0.0045      0.012     -0.381      0.703        -0.028     0.019
# district[T.u'Marina\xa0\xa0']                  -0.2965      0.230     -1.288      0.198        -0.748     0.155
# district[T.u'Mission Terrace\xa0\xa0']          0.0246      0.008      3.205      0.001         0.010     0.040
# district[T.u'Nob Hill\xa0\xa0']                -0.1961      0.153     -1.279      0.201        -0.497     0.104
# district[T.u'North Beach\xa0\xa0']             -0.1974      0.154     -1.284      0.199        -0.499     0.104
# district[T.u'North Waterfront\xa0\xa0']        -0.2116      0.153     -1.379      0.168        -0.512     0.089
# district[T.u'Outer Mission\xa0\xa0']            0.0081      0.008      1.056      0.291        -0.007     0.023
# district[T.u'Pacific Heights\xa0\xa0']         -0.2923      0.230     -1.270      0.204        -0.744     0.159
# district[T.u'Portola\xa0\xa0']                  0.0103      0.007      1.403      0.161        -0.004     0.025
# district[T.u'Presidio Heights\xa0\xa0']        -0.2930      0.230     -1.273      0.203        -0.744     0.158
# district[T.u'Russian Hill\xa0\xa0']            -0.1872      0.153     -1.221      0.222        -0.488     0.113
# district[T.u'Silver Terrace\xa0\xa0']       -5.111e-05      0.008     -0.007      0.995        -0.015     0.015
# district[T.u'Telegraph Hill\xa0\xa0']          -0.1852      0.153     -1.207      0.227        -0.486     0.116
# district[T.u'Van Ness/Civic Cente\xa0\xa0']    -0.2044      0.154     -1.331      0.183        -0.505     0.097
# district[T.u'Visitacion Valley\xa0\xa0']       -0.0080      0.007     -1.065      0.287        -0.023     0.007
# bedroom                                         0.0032      0.001      3.062      0.002         0.001     0.005
# bath                                           -0.0008      0.001     -0.645      0.519        -0.003     0.002
# parking                                         0.0050      0.001      4.488      0.000         0.003     0.007
# sqft                                         5.742e-06   1.46e-06      3.924      0.000      2.87e-06  8.61e-06
# home_own_ass                                 6.904e-07   1.08e-06      0.640      0.522     -1.42e-06   2.8e-06
# day_on_market                                  -0.0005   1.57e-05    -32.047      0.000        -0.001    -0.000
# np.log10(list_price)                            0.9116      0.006    160.997      0.000         0.900     0.923
# single_f_h                                     -0.3354      0.265     -1.268      0.205        -0.854     0.183
# condo                                          -0.3481      0.265     -1.315      0.189        -0.867     0.171
# dist_no                                        -0.1087      0.077     -1.412      0.158        -0.260     0.042
# sold_year                                       0.0013      0.001      1.687      0.092        -0.000     0.003
# sold_month                                     -0.0002      0.000     -1.013      0.311        -0.001     0.000
# ==============================================================================
# Omnibus:                      313.181   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1042.246
# Skew:                           0.329   Prob(JB):                    4.78e-227
# Kurtosis:                       5.309   Cond. No.                     1.03e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.8e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
model_sold_no_list= smf.ols(formula='np.log10(sale_price) ~ district + bedroom + bath + parking + sqft + home_own_ass + day_on_market + single_f_h + condo + dist_no + sold_year + sold_month', data=df_sold)
linreg4 = model_sold_no_list.fit()
print '\nmodel without list price: ', linreg4.summary()
# Out:
# model without list price:                               OLS Regression Results
# ================================================================================
# Dep. Variable:     np.log10(sale_price)   R-squared:                       0.858
# Model:                              OLS   Adj. R-squared:                  0.856
# Method:                   Least Squares   F-statistic:                     810.1
# Date:                  Mon, 28 Nov 2016   Prob (F-statistic):               0.00
# Time:                          01:58:27   Log-Likelihood:                 3340.7
# No. Observations:                  4339   AIC:                            -6615.
# Df Residuals:                      4306   BIC:                            -6405.
# Df Model:                            32
# Covariance Type:              nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                     -23.3689      1.352    -17.290      0.000       -26.019   -20.719
# district[T.u'Bayview\xa0\xa0']                 -0.0093      0.019     -0.490      0.625        -0.046     0.028
# district[T.u'Candlestick Point\xa0\xa0']        0.0602      0.024      2.490      0.013         0.013     0.108
# district[T.u'Cow Hollow\xa0\xa0']             -10.1727      0.588    -17.308      0.000       -11.325    -9.020
# district[T.u'Crocker Amazon\xa0\xa0']           0.0526      0.020      2.650      0.008         0.014     0.092
# district[T.u'Downtown\xa0\xa0']                -6.8358      0.392    -17.452      0.000        -7.604    -6.068
# district[T.u'Excelsior\xa0\xa0']                0.0703      0.019      3.682      0.000         0.033     0.108
# district[T.u'Financial District\xa0\xa0']      -6.6922      0.392    -17.081      0.000        -7.460    -5.924
# district[T.u'Hunters Point\xa0\xa0']            0.0714      0.029      2.432      0.015         0.014     0.129
# district[T.u'Little Hollywood\xa0\xa0']         0.0806      0.031      2.571      0.010         0.019     0.142
# district[T.u'Marina\xa0\xa0']                 -10.1960      0.588    -17.351      0.000       -11.348    -9.044
# district[T.u'Mission Terrace\xa0\xa0']          0.1336      0.020      6.592      0.000         0.094     0.173
# district[T.u'Nob Hill\xa0\xa0']                -6.7009      0.392    -17.098      0.000        -7.469    -5.933
# district[T.u'North Beach\xa0\xa0']             -6.7582      0.393    -17.213      0.000        -7.528    -5.988
# district[T.u'North Waterfront\xa0\xa0']        -6.7942      0.392    -17.341      0.000        -7.562    -6.026
# district[T.u'Outer Mission\xa0\xa0']            0.0563      0.020      2.779      0.005         0.017     0.096
# district[T.u'Pacific Heights\xa0\xa0']        -10.1972      0.588    -17.355      0.000       -11.349    -9.045
# district[T.u'Portola\xa0\xa0']                  0.0796      0.019      4.096      0.000         0.041     0.118
# district[T.u'Presidio Heights\xa0\xa0']       -10.2041      0.587    -17.369      0.000       -11.356    -9.052
# district[T.u'Russian Hill\xa0\xa0']            -6.6446      0.392    -16.956      0.000        -7.413    -5.876
# district[T.u'Silver Terrace\xa0\xa0']           0.0262      0.021      1.262      0.207        -0.015     0.067
# district[T.u'Telegraph Hill\xa0\xa0']          -6.6660      0.392    -16.997      0.000        -7.435    -5.897
# district[T.u'Van Ness/Civic Cente\xa0\xa0']    -6.8269      0.392    -17.422      0.000        -7.595    -6.059
# district[T.u'Visitacion Valley\xa0\xa0']        0.0042      0.020      0.212      0.832        -0.035     0.043
# bedroom                                         0.0320      0.003     11.619      0.000         0.027     0.037
# bath                                            0.0401      0.003     11.795      0.000         0.033     0.047
# parking                                         0.0362      0.003     12.576      0.000         0.031     0.042
# sqft                                            0.0001   3.48e-06     31.528      0.000         0.000     0.000
# home_own_ass                                 4.925e-05   2.74e-06     17.959      0.000      4.39e-05  5.46e-05
# day_on_market                                  -0.0006   4.16e-05    -13.990      0.000        -0.001    -0.001
# single_f_h                                    -11.6325      0.676    -17.214      0.000       -12.957   -10.308
# condo                                         -11.7364      0.676    -17.366      0.000       -13.061   -10.411
# dist_no                                        -3.5415      0.196    -18.082      0.000        -3.926    -3.158
# sold_year                                       0.0377      0.002     19.047      0.000         0.034     0.042
# sold_month                                      0.0016      0.001      2.985      0.003         0.001     0.003
# ==============================================================================
# Omnibus:                      950.530   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10126.515
# Skew:                          -0.734   Prob(JB):                         0.00
# Kurtosis:                      10.339   Cond. No.                     1.03e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.8e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
print linreg4.fittedvalues[4000:4031]
# Out:
# sold
# 2016-08-16    6.076725
# 2016-08-16    5.832863
# 2016-08-16    5.797175
# 2016-08-16    6.121360
# 2016-08-16    6.789407
# 2016-08-17    6.118716
# 2016-08-17    5.969873
# 2016-08-17    5.804895
# 2016-08-17    6.043624
# 2016-08-17    5.552061
# 2016-08-17    5.810634
# 2016-08-18    5.933694
# 2016-08-18    6.261910
# 2016-08-18    5.983631
# 2016-08-18    6.191124
# 2016-08-19    6.177897
# 2016-08-19    5.721197
# 2016-08-19    5.882037
# 2016-08-19    5.832333
# 2016-08-19    5.871756
# 2016-08-19    6.263388
# 2016-08-19    6.315339
# 2016-08-19    6.169405
# 2016-08-19    5.856410
# 2016-08-19    6.391274
# 2016-08-19    6.057712
# 2016-08-19    5.998529
# 2016-08-19    5.907762
# 2016-08-22    6.167572
# 2016-08-22    6.143602
# 2016-08-22    5.858712
# dtype: float64

# %%
print 'Date        Sale price  Pred. with list p    W/o list p     W and W/o diff'
for i in xrange(30):
    print df_sold.index[4000+i].date(), '    ', df_sold.sale_price[4000+i], '    ', np.around(np.power(10, linreg3.fittedvalues[4000+i]), decimals = 2), '     ', np.around(np.power(10, linreg4.fittedvalues[4000+i]), decimals = 2), '    ',np.around(np.power(10,linreg3.fittedvalues[4000+i])-np.power(10,linreg4.fittedvalues[4000+i]), decimals = 2)
# Out:
# Date        Sale price  Pred. with list p    W/o list p     W and W/o diff
# 2016-08-16      917500      1025959.83       1193233.28      -167273.44
# 2016-08-16      850000      834018.92       680554.19      153464.73
# 2016-08-16      670000      653762.02       626866.74      26895.29
# 2016-08-16      980000      1040460.76       1322391.78      -281931.02
# 2016-08-16      9750000      9770958.09       6157536.68      3613421.42
# 2016-08-17      1100000      1065411.54       1314364.55      -248953.01
# 2016-08-17      1050000      1136881.33       932981.43      203899.9
# 2016-08-17      775000      806083.35       638109.24      167974.12
# 2016-08-17      699000      802734.47       1105665.1      -302930.62
# 2016-08-17      385000      366568.29       356501.1      10067.19
# 2016-08-17      790000      726309.25       646598.11      79711.14
# 2016-08-18      755000      726028.55       858409.46      -132380.9
# 2016-08-18      1850000      1846804.93       1827720.88      19084.05
# 2016-08-18      760000      823950.75       963011.33      -139060.59
# 2016-08-18      1475000      1707527.18       1552829.88      154697.3
# 2016-08-19      1450000      1506452.54       1506251.37      201.17
# 2016-08-19      595000      622486.89       526256.19      96230.7
# 2016-08-19      805000      800827.73       762143.41      38684.32
# 2016-08-19      765000      717364.66       679725.12      37639.54
# 2016-08-19      850000      876679.73       744313.73      132366.0
# 2016-08-19      2150000      2265643.68       1833952.08      431691.6
# 2016-08-19      2500000      2503779.98       2066991.84      436788.14
# 2016-08-19      1200000      1328905.56       1477084.41      -148178.86
# 2016-08-19      925000      808930.33       718472.01      90458.32
# 2016-08-19      3091000      3127972.66       2461917.96      666054.7
# 2016-08-19      779000      853464.98       1142121.89      -288656.9
# 2016-08-19      640000      638044.91       996618.11      -358573.2
# 2016-08-19      715000      712549.59       808652.17      -96102.58
# 2016-08-22      1710000      1608333.27       1470861.41      137471.86
# 2016-08-22      1050000      1058795.36       1391882.14      -333086.77

# %%
df_district = pd.get_dummies(df_sold.district)
df_sold_dum = pd.concat( [df_sold, df_district], axis=1)

# %%
df_sold_dum.head(1)
# Out:
#                      address       district  bedroom  bath  parking  sqft  \
# sold
# 2013-11-12  20 Vandewater St  North Beach          2   2.0        1  1456
#
#             dollar_sqft  home_own_ass  day_on_market  list_price  \
# sold
# 2013-11-12   776.098901         565.0             38     1195000
#
#                    ...           North Waterfront    Outer Mission    \
# sold               ...
# 2013-11-12         ...                            0                0
#
#             Pacific Heights    Portola    Presidio Heights    Russian Hill    \
# sold
# 2013-11-12                  0          0                   0               0
#
#             Silver Terrace    Telegraph Hill    Van Ness/Civic Cente    \
# sold
# 2013-11-12                 0                 0                       0
#
#             Visitacion Valley
# sold
# 2013-11-12                    0
#
# [1 rows x 41 columns]

# %%
df_sold_dum.pop('district')
df_sold_dum.pop('address')
# Out:
# sold
# 2013-11-12            20 Vandewater St
# 2013-11-12        946 Stockton St #14A
# 2013-11-12               930 Pine #211
# 2013-11-13             2921 Jackson St
# 2013-11-13           1299 Bush St #604
# 2013-11-13          3417 Divisadero St
# 2013-11-13               873 Meade Ave
# 2013-11-13      2466 Francisco St #102
# 2013-11-13     2211 California St #407
# 2013-11-13             2469 Vallejo St
# 2013-11-13               779 Sweeny St
# 2013-11-13    1626 North Point St #202
# 2013-11-13         2821 Buchanan St #2
# 2013-11-13             2055 Thomas Ave
# 2013-11-13        950 Stockton St #201
# 2013-11-14               2 Robinson Dr
# 2013-11-14               129 Pixley St
# 2013-11-14        1177 California #225
# 2013-11-14            2813 Buchanan St
# 2013-11-14           2775 Greenwich St
# 2013-11-15             1418 Ingalls St
# 2013-11-15    1 Daniel Burnham Ct #216
# 2013-11-15         62-62 Bridgeview Dr
# 2013-11-15           1001 Pine St #312
# 2013-11-15                3228 Clay St
# 2013-11-15               49 Wabash Ter
# 2013-11-15                966 Ingerson
# 2013-11-15           147 Baltimore Way
# 2013-11-15              1642 Palou Ave
# 2013-11-15          3423 Divisadero St
#                         ...
# 2016-10-28         1925 Pacific Ave #4
# 2016-10-28          1650 Broadway #101
# 2016-10-28          2640 Divisadero St
# 2016-10-28               283 Madrid St
# 2016-10-28             2244 Steiner St
# 2016-10-31           1299 Bush St #201
# 2016-10-31         1520 Taylor St #603
# 2016-10-31          637 Powell St #401
# 2016-11-01          3235 Gough St #206
# 2016-11-01            864 Francisco St
# 2016-11-01          3333 Divisadero St
# 2016-11-01              1408 Rankin St
# 2016-11-02          333 Grant Ave #402
# 2016-11-02           454 Lombard St #4
# 2016-11-02          1688 Pine St #E803
# 2016-11-02          1688 Pine St #E707
# 2016-11-02              2507-A Polk St
# 2016-11-02           650 Turk St #T405
# 2016-11-03           2764 Greenwich St
# 2016-11-03           25 Hotaling Pl #H
# 2016-11-04               61 De Long St
# 2016-11-04      750 Van Ness Ave #V205
# 2016-11-04              239 Arleta Ave
# 2016-11-04           10-12 Aladdin Ter
# 2016-11-04        111 Chestnut St #806
# 2016-11-04             1100 Union #500
# 2016-11-08           2775 Greenwich St
# 2016-11-08          1441 Jones St #404
# 2016-11-08     1800 Washington St #211
# 2016-11-08                 25 Rico Way
# Name: address, dtype: object

# %%
df_sold_dum.head(1)
# Out:
#             bedroom  bath  parking  sqft  dollar_sqft  home_own_ass  \
# sold
# 2013-11-12        2   2.0        1  1456   776.098901         565.0
#
#             day_on_market  list_price  sale_price  sale_to_list_ratio  \
# sold
# 2013-11-12             38     1195000     1130000           94.560669
#
#                    ...           North Waterfront    Outer Mission    \
# sold               ...
# 2013-11-12         ...                            0                0
#
#             Pacific Heights    Portola    Presidio Heights    Russian Hill    \
# sold
# 2013-11-12                  0          0                   0               0
#
#             Silver Terrace    Telegraph Hill    Van Ness/Civic Cente    \
# sold
# 2013-11-12                 0                 0                       0
#
#             Visitacion Valley
# sold
# 2013-11-12                    0
#
# [1 rows x 39 columns]

# %%
y_sold = df_sold_dum.pop('sale_price')
#y_sold = np.log10(y_sold)

X_sold = df_sold_dum
X_sold.pop('dollar_sqft')
X_sold.pop('sale_to_list_ratio')
# Out:
# sold
# 2013-11-12     94.560669
# 2013-11-12    119.000000
# 2013-11-12    101.836394
# 2013-11-13    104.194858
# 2013-11-13    112.903226
# 2013-11-13     95.783252
# 2013-11-13     99.582463
# 2013-11-13     98.401387
# 2013-11-13    106.112054
# 2013-11-13    108.488372
# 2013-11-13    114.758497
# 2013-11-13     96.000000
# 2013-11-13    102.307692
# 2013-11-13    102.040816
# 2013-11-13    113.839286
# 2013-11-14     98.690293
# 2013-11-14    117.007535
# 2013-11-14     92.929293
# 2013-11-14    118.750000
# 2013-11-14     95.661846
# 2013-11-15    110.200364
# 2013-11-15    105.210421
# 2013-11-15    116.861436
# 2013-11-15     93.533703
# 2013-11-15    105.014749
# 2013-11-15    107.214429
# 2013-11-15    112.474438
# 2013-11-15    101.522843
# 2013-11-15    119.153675
# 2013-11-15    100.000000
#                  ...
# 2016-10-28    116.991643
# 2016-10-28     97.116279
# 2016-10-28    103.753910
# 2016-10-28    121.869783
# 2016-10-28     92.307692
# 2016-10-31     87.932080
# 2016-10-31     92.465753
# 2016-10-31    104.522613
# 2016-11-01    109.887359
# 2016-11-01    100.000000
# 2016-11-01    107.947434
# 2016-11-01    120.200334
# 2016-11-02    100.549451
# 2016-11-02    103.669065
# 2016-11-02    100.000000
# 2016-11-02    100.000000
# 2016-11-02    112.488084
# 2016-11-02    104.565538
# 2016-11-03     97.790773
# 2016-11-03     99.528857
# 2016-11-04     91.435103
# 2016-11-04     98.872180
# 2016-11-04     80.000000
# 2016-11-04    110.275689
# 2016-11-04    100.000000
# 2016-11-04     97.357992
# 2016-11-08    109.628217
# 2016-11-08     86.666667
# 2016-11-08     99.745763
# 2016-11-08    100.000000
# Name: sale_to_list_ratio, dtype: float64

# %%
X_sold.head(3)
# Out:
#             bedroom  bath  parking  sqft  home_own_ass  day_on_market  \
# sold
# 2013-11-12        2   2.0        1  1456        565.00             38
# 2013-11-12        2   1.5        0   744        556.00              8
# 2013-11-12        1   1.0        1   700        511.14             35
#
#             list_price  single_f_h  condo  dist_no         ...           \
# sold                                                       ...
# 2013-11-12     1195000           0      1        8         ...
# 2013-11-12      500000           0      1        8         ...
# 2013-11-12      599000           0      1        8         ...
#
#             North Waterfront    Outer Mission    Pacific Heights    Portola    \
# sold
# 2013-11-12                   0                0                  0          0
# 2013-11-12                   0                0                  0          0
# 2013-11-12                   0                0                  0          0
#
#             Presidio Heights    Russian Hill    Silver Terrace    \
# sold
# 2013-11-12                   0               0                 0
# 2013-11-12                   0               0                 0
# 2013-11-12                   0               0                 0
#
#             Telegraph Hill    Van Ness/Civic Cente    Visitacion Valley
# sold
# 2013-11-12                 0                       0                    0
# 2013-11-12                 0                       0                    0
# 2013-11-12                 0                       0                    0
#
# [3 rows x 36 columns]

# %%
y_sold.head(3)
# Out:
# sold
# 2013-11-12    1130000
# 2013-11-12     595000
# 2013-11-12     610000
# Name: sale_price, dtype: int64

# %%
X_train = X_sold[:3500]
X_test = X_sold[3500:4000]
X_val = X_sold[4000:]

y_train = y_sold[:3500]
y_test = y_sold[3500:4000]
y_val = y_sold[4000:]

# %%
X_train.shape
# Out:
# (3500, 36)

# %%
y_train.shape
# Out:
# (3500,)

# %%
X_test.shape
# Out:
# (500, 36)

# %%
y_test.shape
# Out:
# (500,)

# %%
lr1 = linear_model.LinearRegression(normalize = True)
lr1.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
print 'lr1 no log10 Train Coefficients: \n', np.around(lr1.coef_, decimals = 4)
# Out:
# lr1 no log10 Train Coefficients:
# [  2.03919217e+04   4.90872730e+04   2.03304411e+04   7.00660000e+00
#    1.88518000e+01  -2.05751970e+03   8.51200000e-01   2.55031253e+18
#    2.55031253e+18  -1.01260409e+18   2.95200533e+04   3.57788200e+02
#    5.92995450e+18   5.92995450e+18   5.92995450e+18   2.89214222e+18
#    5.92995450e+18   3.90474632e+18   5.92995450e+18   3.90474632e+18
#    5.92995450e+18   5.92995450e+18   2.89214222e+18   5.92995450e+18
#    3.90474632e+18   3.90474632e+18   3.90474632e+18   5.92995450e+18
#    2.89214222e+18   5.92995450e+18   2.89214222e+18   3.90474632e+18
#    5.92995450e+18   3.90474632e+18   3.90474632e+18   5.92995450e+18]

# %%
len(lr1.coef_)
# Out:
# 36

# %%
for i in range(len(lr1.coef_)):
    print np.round(lr1.coef_[i], 4)
# Out:
# 20391.9217
# 49087.273
# 20330.4411
# 7.0066
# 18.8518
# -2057.5197
# 0.8512
# 2.55031252625e+18
# 2.55031252625e+18
# -1.01260409376e+18
# 29520.0533
# 357.7882
# 5.92995450329e+18
# 5.92995450329e+18
# 5.92995450329e+18
# 2.89214222201e+18
# 5.92995450329e+18
# 3.90474631577e+18
# 5.92995450329e+18
# 3.90474631577e+18
# 5.92995450329e+18
# 5.92995450329e+18
# 2.89214222201e+18
# 5.92995450329e+18
# 3.90474631577e+18
# 3.90474631577e+18
# 3.90474631577e+18
# 5.92995450329e+18
# 2.89214222201e+18
# 5.92995450329e+18
# 2.89214222201e+18
# 3.90474631577e+18
# 5.92995450329e+18
# 3.90474631577e+18
# 3.90474631577e+18
# 5.92995450329e+18

# %%
print('lr1 no log10 Train Variance score: %.2f' % lr1.score(X_train, y_train))
# Out:
# lr1 no log10 Train Variance score: 0.98

# %%
predicted_t1 = cross_val_predict(lr1, X_train, y_train, cv=10)

# %%
predicted_t1[0:20]
# Out:
# array([ 1194496.,   626176.,   601216.,  3871616.,   617600.,  1253376.,
#          398976.,   702080.,   725632.,  1844096.,   592000.,  1331200.,
#         1371264.,   582016.,   474496.,   667008.,  1120512.,   483072.,
#         3416192.,   945280.])

# %%
fig, ax = plt.subplots(figsize=(25,15))
fig.suptitle('lr1 no log10 LinearRegression with list price', fontsize=20)
ax.scatter(y_train, predicted_t1)
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', lw=4)
ax.set_xlabel('lr1 no log10 Train set Measured', fontsize=20)
ax.set_ylabel('lr1 no log10 Train set Predicted', fontsize=20)
plt.show()

# %%
print('lr1 no log10 Test Variance score: %.2f' % lr1.score(X_test, y_test))
# Out:
# lr1 no log10 Test Variance score: 0.96

# %%
predicted_test1 = cross_val_predict(lr1, X_test, y_test, cv=10)

fig, ax = plt.subplots(figsize=(25,15))
fig.suptitle('lr1 no log10 LinearRegression with list price', fontsize=20)
ax.scatter(y_test, predicted_test1)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('lr1 no log10 Test set Measured', fontsize=20)
ax.set_ylabel('lr1 no log10 Test set Predicted', fontsize=20)
plt.show()

# %%
print('lr1 no log10 Validation Variance score: %.2f' % lr1.score(X_val, y_val))

# Train
predicted_val = cross_val_predict(lr1, X_val, y_val, cv=10)

fig, ax = plt.subplots(figsize=(25,15))
fig.suptitle('lr1 no log10 LinearRegression with list price', fontsize=20)
ax.scatter(y_val, predicted_val)
ax.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'k--', lw=4)
ax.set_xlabel('lr1 no log10 Validation set Measured', fontsize=20)
ax.set_ylabel('lr1 no log10 Validation set Predicted', fontsize=20)
plt.show()
# Out:
# lr1 no log10 Validation Variance score: 0.98

# %%
X_train = X_sold[:4000]
X_test = X_sold[4000:]

y_train = y_sold[:4000]
y_test = y_sold[4000:]

# %%
lr2 = linear_model.LinearRegression()
lr2.fit(X_train, y_train)

# The coefficients
print 'lr2 Train Coefficients: \n', lr2.coef_
# Explained variance score: 1 is perfect prediction
print('lr2 Train Variance score: %.2f' % lr2.score(X_train, y_train))
# Out:
# lr2 Train Coefficients:
# [  1.16185167e+04   4.41667839e+04   1.96791378e+04   2.34391535e+01
#    1.59532405e+01  -2.17406187e+03   8.54372046e-01   7.75127025e+04
#   -7.75127025e+04  -9.16886767e+04   1.67346270e+04  -7.81616833e+02
#   -1.44450654e+04  -1.17945798e+04   6.21583681e+04  -1.18467388e+04
#   -1.81826921e+04  -4.18111110e+04  -1.71830688e+04  -9.78973161e+03
#    8.62340382e+04   9.74125463e+03  -2.87488132e+04   3.34895188e+04
#    1.42611352e+04  -2.68252046e+04  -5.35007288e+04  -2.29430330e+04
#   -4.80792945e+03  -2.11459869e+04   1.24742320e+05   6.50372314e+04
#   -3.75370728e+04   9.23744679e+03  -2.97729562e+04  -5.45666002e+04]
# lr2 Train Variance score: 0.98

# %%
lr2 = linear_model.LinearRegression(normalize=True)
lr2.fit(X_train, y_train)

# The coefficients
print 'lr2 Train Coefficients: \n', lr2.coef_
# Explained variance score: 1 is perfect prediction
print('lr2 Train Variance score: %.2f' % lr2.score(X_train, y_train))
# Out:
# lr2 Train Coefficients:
# [  1.15304506e+04   4.42094188e+04   1.96575265e+04   2.34595466e+01
#    1.59578545e+01  -2.17405560e+03   8.54373847e-01  -1.31658642e+15
#   -1.31658642e+15   5.07022611e+16   1.67530136e+04  -7.79218954e+02
#   -3.09563683e+16  -3.09563683e+16  -3.09563683e+16   1.21150415e+17
#   -3.09563683e+16   7.04481540e+16  -3.09563683e+16   7.04481540e+16
#   -3.09563683e+16  -3.09563683e+16   1.21150415e+17  -3.09563683e+16
#    7.04481540e+16   7.04481540e+16   7.04481540e+16  -3.09563683e+16
#    1.21150415e+17  -3.09563683e+16   1.21150415e+17   7.04481540e+16
#   -3.09563683e+16   7.04481540e+16   7.04481540e+16  -3.09563683e+16]
# lr2 Train Variance score: 0.98

# %%
predicted_train2 = cross_val_predict(lr2, X_train, y_train, cv=10)

fig, ax = plt.subplots(figsize=(25,15))
fig.suptitle('lr2 LinearRegression with list price', fontsize=20)
ax.scatter(y_train, predicted_train2)
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', lw=4)
ax.set_xlabel('lr2 Train set Measured', fontsize=20)
ax.set_ylabel('lr2 Train set Predicted', fontsize=20)
plt.show()

# %%
print('lr2 Test Variance score: %.2f' % lr2.score(X_test, y_test))

# Train
predicted_test2 = cross_val_predict(lr2, X_test, y_test, cv=10)

fig, ax = plt.subplots(figsize=(25,15))
fig.suptitle('lr2 LinearRegression with list price', fontsize=20)
ax.scatter(y_test, predicted_test2)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('lr2 Test set Measured', fontsize=20)
ax.set_ylabel('lr2 Test set Predicted', fontsize=20)
plt.show()
# Out:
# lr2 Test Variance score: 0.98

# %%
X_train.pop('list_price')
X_test.pop('list_price')
# Train

lr3 = linear_model.LinearRegression()
lr3.fit(X_train, y_train)

# The coefficients
print 'no list price Train Coefficients: \n', lr3.coef_
# Explained variance score: 1 is perfect prediction
print('no list price Train Variance score: %.2f' % lr3.score(X_train, y_train))

# Train
predicted_train3 = cross_val_predict(lr3, X_train, y_train, cv=10)

fig, ax = plt.subplots(figsize=(25,15))
fig.suptitle('lr3 LinearRegression without list price', fontsize=20)
ax.scatter(y_train, predicted_train3)
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', lw=4)
ax.set_xlabel('lr3 Train set Measured', fontsize=20)
ax.set_ylabel('lr3 Train set Predicted', fontsize=20)
plt.show()
# Out:
# no list price Train Coefficients:
# [ -1.96389358e+05   1.77720604e+05   8.25418320e+04   1.16667942e+03
#    1.47177831e+02  -9.30055334e+02   3.57559691e+05  -3.57559691e+05
#   -4.40609801e+05   1.28491004e+05   3.88247759e+03  -1.97681688e+05
#   -1.21765809e+05   3.67265952e+05  -5.51013030e+04  -1.66581094e+05
#    2.86474889e+04  -1.24925038e+05   1.43997708e+05   3.63462876e+05
#    9.52852310e+04  -2.71812304e+05  -7.81295352e+04   1.17697564e+05
#    4.75252650e+04  -1.06855041e+05  -1.69882071e+05  -9.77697374e+04
#   -1.37905854e+05  -2.97841550e+04   3.89365240e+05  -1.16946868e+05
#    3.16572515e+05  -3.49445916e+04  -1.59734751e+05]
# no list price Train Variance score: 0.81

# %%
print('lr3 Test Variance score: %.2f' % lr3.score(X_test, y_test))

# Train
predicted_test3 = cross_val_predict(lr3, X_test, y_test, cv=10)

fig, ax = plt.subplots(figsize=(25,15))
fig.suptitle('lr3 LinearRegression without list price', fontsize=20)
ax.scatter(y_test, predicted_test3)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('lr3 Test set Measured', fontsize=20)
ax.set_ylabel('lr3 Test set Predicted', fontsize=20)
plt.show()
# Out:
# lr3 Test Variance score: 0.77

# %%
X_sold.head(1)
# Out:
#             bedroom  bath  parking  sqft  home_own_ass  day_on_market  \
# sold
# 2013-11-12        2   2.0        1  1456         565.0             38
#
#             list_price  single_f_h  condo  dist_no         ...           \
# sold                                                       ...
# 2013-11-12     1195000           0      1        8         ...
#
#             North Waterfront    Outer Mission    Pacific Heights    Portola    \
# sold
# 2013-11-12                   0                0                  0          0
#
#             Presidio Heights    Russian Hill    Silver Terrace    \
# sold
# 2013-11-12                   0               0                 0
#
#             Telegraph Hill    Van Ness/Civic Cente    Visitacion Valley
# sold
# 2013-11-12                 0                       0                    0
#
# [1 rows x 36 columns]

# %%
y_sold.head(1)
# Out:
# sold
# 2013-11-12    1130000
# Name: sale_price, dtype: int64

# %%
# The whole set
X_sold.pop('list_price')
predicted_all = cross_val_predict(lr3, X_sold, y_sold, cv=10)

fig, ax = plt.subplots(figsize=(25,15))
fig.suptitle('whole set LinearRegression without list price', fontsize=20)
ax.scatter(y_sold, predicted_all)
ax.plot([y_sold.min(), y_sold.max()], [y_sold.min(), y_sold.max()], 'k--', lw=4)
ax.set_xlabel('Measured', fontsize=20)
ax.set_ylabel('Predicted', fontsize=20)
plt.show()

# %%
print('lr3 All Variance score: %.2f' % lr3.score(X_sold, y_sold))
# Out:
# lr3 All Variance score: 0.80

# %%
print 'Date        Square-Foot     Sale-price    Predicted price w LP   Predicted w/o LP    S-P error'
for i in xrange(30):
    print X_test.index[i].date(),'     ', X_test.sqft[i],'     ', y_test[i], '     ', predicted_test2[i], '     ', predicted_test3[i], '    ', y_test[i]-predicted_test2[i]
# Out:
# Date        Square-Foot     Sale-price    Predicted price w LP   Predicted w/o LP    S-P error
# 2016-08-16       700       917500       1179648.0       1349046.67804      -262148.0
# 2016-08-16       1312       850000       720896.0       1055932.213      129104.0
# 2016-08-16       760       670000       524288.0       -15857.413444      145712.0
# 2016-08-16       1050       980000       983040.0       1301797.75862      -3040.0
# 2016-08-16       4617       9750000       8650752.0       6936240.33525      1099248.0
# 2016-08-17       1140       1100000       983040.0       687347.43916      116960.0
# 2016-08-17       1210       1050000       983040.0       403594.249367      66960.0
# 2016-08-17       1000       775000       655360.0       566029.959602      119640.0
# 2016-08-17       550       699000       917504.0       719862.401498      -218504.0
# 2016-08-17       527       385000       -65536.0       -47478.1680219      450536.0
# 2016-08-17       975       790000       589824.0       301756.661431      200176.0
# 2016-08-18       1290       755000       917504.0       608152.889896      -162504.0
# 2016-08-18       1841       1850000       1900544.0       3473133.3677      -50544.0
# 2016-08-18       460       760000       851968.0       870198.456703      -91968.0
# 2016-08-18       1350       1475000       1638400.0       1806784.30057      -163400.0
# 2016-08-19       1382       1450000       1769472.0       3510544.9679      -319472.0
# 2016-08-19       825       595000       524288.0       134341.750826      70712.0
# 2016-08-19       1394       805000       917504.0       1068491.91912      -112504.0
# 2016-08-19       1200       765000       524288.0       523495.338861      240712.0
# 2016-08-19       900       850000       655360.0       1288028.68568      194640.0
# 2016-08-19       1710       2150000       2097152.0       1681686.16744      52848.0
# 2016-08-19       2224       2500000       2686976.0       4177614.1567      -186976.0
# 2016-08-19       985       1200000       1441792.0       1416761.85008      -241792.0
# 2016-08-19       1300       925000       655360.0       1022072.53275      269640.0
# 2016-08-19       2076       3091000       2949120.0       2607185.94872      141880.0
# 2016-08-19       650       779000       851968.0       756396.758968      -72968.0
# 2016-08-19       534       640000       524288.0       403525.718643      115712.0
# 2016-08-19       751       715000       655360.0       864035.194052      59640.0
# 2016-08-22       1200       1710000       1638400.0       700419.137393      71600.0
# 2016-08-22       966       1050000       1114112.0       1274439.5468      -64112.0

# %%
print 'Date        Square-Foot     Sale-price  Pred. w LP   Pred. w/o LP    S-P error'
for i in xrange(30):
    print X_test.index[i].date(),'     ', X_test.sqft[i],'     ', y_test[i], '     ', np.round(predicted_test2[i], 2), '     ', np.round(predicted_all[i], 2), '    ', np.round(y_test[i]-predicted_all[i], 2)
# Out:
# Date        Square-Foot     Sale-price  Pred. w LP   Pred. w/o LP    S-P error
# 2016-08-16       700       917500       1179648.0       1264019.52      -346519.52
# 2016-08-16       1312       850000       720896.0       353802.97      496197.03
# 2016-08-16       760       670000       524288.0       310675.35      359324.65
# 2016-08-16       1050       980000       983040.0       3862669.11      -2882669.11
# 2016-08-16       4617       9750000       8650752.0       191424.35      9558575.65
# 2016-08-17       1140       1100000       983040.0       925056.45      174943.55
# 2016-08-17       1210       1050000       983040.0       -325253.87      1375253.87
# 2016-08-17       1000       775000       655360.0       621196.98      153803.02
# 2016-08-17       550       699000       917504.0       493983.21      205016.79
# 2016-08-17       527       385000       -65536.0       2056042.0      -1671042.0
# 2016-08-17       975       790000       589824.0       -101076.35      891076.35
# 2016-08-18       1290       755000       917504.0       1597962.58      -842962.58
# 2016-08-18       1841       1850000       1900544.0       1118543.16      731456.84
# 2016-08-18       460       760000       851968.0       124056.34      635943.66
# 2016-08-18       1350       1475000       1638400.0       1354812.21      120187.79
# 2016-08-19       1382       1450000       1769472.0       112448.99      1337551.01
# 2016-08-19       825       595000       524288.0       723231.43      -128231.43
# 2016-08-19       1394       805000       917504.0       581346.51      223653.49
# 2016-08-19       1200       765000       524288.0       4134311.73      -3369311.73
# 2016-08-19       900       850000       655360.0       505146.49      344853.51
# 2016-08-19       1710       2150000       2097152.0       462499.54      1687500.46
# 2016-08-19       2224       2500000       2686976.0       339021.87      2160978.13
# 2016-08-19       985       1200000       1441792.0       1114208.95      85791.05
# 2016-08-19       1300       925000       655360.0       190790.46      734209.54
# 2016-08-19       2076       3091000       2949120.0       1886840.2      1204159.8
# 2016-08-19       650       779000       851968.0       607370.69      171629.31
# 2016-08-19       534       640000       524288.0       24433.56      615566.44
# 2016-08-19       751       715000       655360.0       370836.48      344163.52
# 2016-08-22       1200       1710000       1638400.0       320383.52      1389616.48
# 2016-08-22       966       1050000       1114112.0       1196626.42      -146626.42

# %%
X_train.head(3)
# Out:
#             bedroom  bath  parking  sqft  home_own_ass  day_on_market  \
# sold
# 2013-11-12        2   2.0        1  1456        565.00             38
# 2013-11-12        2   1.5        0   744        556.00              8
# 2013-11-12        1   1.0        1   700        511.14             35
#
#             single_f_h  condo  dist_no  sold_year         ...           \
# sold                                                      ...
# 2013-11-12           0      1        8       2013         ...
# 2013-11-12           0      1        8       2013         ...
# 2013-11-12           0      1        8       2013         ...
#
#             North Waterfront    Outer Mission    Pacific Heights    Portola    \
# sold
# 2013-11-12                   0                0                  0          0
# 2013-11-12                   0                0                  0          0
# 2013-11-12                   0                0                  0          0
#
#             Presidio Heights    Russian Hill    Silver Terrace    \
# sold
# 2013-11-12                   0               0                 0
# 2013-11-12                   0               0                 0
# 2013-11-12                   0               0                 0
#
#             Telegraph Hill    Van Ness/Civic Cente    Visitacion Valley
# sold
# 2013-11-12                 0                       0                    0
# 2013-11-12                 0                       0                    0
# 2013-11-12                 0                       0                    0
#
# [3 rows x 35 columns]

# %%
y_train.head(3)
# Out:
# sold
# 2013-11-12    1130000
# 2013-11-12     595000
# 2013-11-12     610000
# Name: sale_price, dtype: int64

# %%
X_train.shape
# Out:
# (4000, 35)

# %%
y_train.shape
# Out:
# (4000,)

# %%
X_test.shape
# Out:
# (339, 35)

# %%
y_test.shape
# Out:
# (339,)

# %%
np.log10(y_train).head(3)
# Out:
# sold
# 2013-11-12    6.053078
# 2013-11-12    5.774517
# 2013-11-12    5.785330
# Name: sale_price, dtype: float64

# %%
y_train_log = np.log10(y_train)
y_test_log = np.log10(y_test)

lr_log= linear_model.LinearRegression(normalize = True)
lr_log.fit(X_train, y_train_log)
# Train
print('lr_log Train Variance score: %.2f' % lr_log.score(X_train, y_train_log))
predicted_train_log = cross_val_predict(lr_log, X_train, y_train_log, cv=10)

fig, ax = plt.subplots(figsize=(25,15))
fig.suptitle('lr_log LinearRegression without list price', fontsize=20)
ax.scatter(y_train_log, predicted_train_log)
ax.plot([y_train_log.min(), y_train_log.max()], [y_train_log.min(), y_train_log.max()], 'k--', lw=4)
ax.set_xlabel('lr_log Train set Measured', fontsize=20)
ax.set_ylabel('lr_log Train set Predicted', fontsize=20)
plt.show()
# Out:
# lr_log Train Variance score: 0.86

# %%
print('lr_log Test Variance score: %.2f' % lr_log.score(X_test, y_test_log))

# Train
predicted_test_log = cross_val_predict(lr_log, X_test, y_test_log, cv=10)

fig, ax = plt.subplots(figsize=(25,15))
fig.suptitle('lr_log LinearRegression without list price', fontsize=20)
ax.scatter(y_test_log, predicted_test_log)
ax.plot([y_test_log.min(), y_test_log.max()], [y_test_log.min(), y_test_log.max()], 'k--', lw=4)
ax.set_xlabel('lr_log Test set Measured', fontsize=20)
ax.set_ylabel('lr_log Test set Predicted', fontsize=20)
plt.show()
# Out:
# lr_log Test Variance score: 0.86

# %%
print 'Date        Square-Foot     Sale-price    Predicted price '
for i in xrange(30):
    print X_test.index[i].date(),'     ', X_test.sqft[i],'     ', np.power(10, y_test_log[i]), '     ', np.power(10, predicted_test_log[i]).round(2)
# Out:
# Date        Square-Foot     Sale-price    Predicted price
# 2016-08-16       700       917500.0       1218814.18
# 2016-08-16       1312       850000.0       615265.41
# 2016-08-16       760       670000.0       604296.39
# 2016-08-16       1050       980000.0       1134194.4
# 2016-08-16       4617       9750000.0       5327978.95
# 2016-08-17       1140       1100000.0       1000000.0
# 2016-08-17       1210       1050000.0       835362.55
# 2016-08-17       1000       775000.0       637804.38
# 2016-08-17       550       699000.0       964661.62
# 2016-08-17       527       385000.0       339820.83
# 2016-08-17       975       790000.0       637804.38
# 2016-08-18       1290       755000.0       897687.13
# 2016-08-18       1841       1850000.0       2053525.03
# 2016-08-18       460       760000.0       835362.55
# 2016-08-18       1350       1475000.0       1382372.23
# 2016-08-19       1382       1450000.0       2738419.63
# 2016-08-19       825       595000.0       532797.89
# 2016-08-19       1394       805000.0       791475.54
# 2016-08-19       1200       765000.0       649381.63
# 2016-08-19       900       850000.0       835362.55
# 2016-08-19       1710       2150000.0       1654817.1
# 2016-08-19       2224       2500000.0       3050527.89
# 2016-08-19       985       1200000.0       1357727.14
# 2016-08-19       1300       925000.0       723394.16
# 2016-08-19       2076       3091000.0       2206734.07
# 2016-08-19       650       779000.0       1018151.72
# 2016-08-19       534       640000.0       777365.03
# 2016-08-19       751       715000.0       913981.7
# 2016-08-22       1200       1710000.0       1134194.4
# 2016-08-22       966       1050000.0       1175743.27

# %%
print 'Date        Sale price  Pred. with list p    W/o list p     W - W/o diff'
for i in xrange(30):
    print df_sold.index[4000+i].date(), '    ', df_sold.sale_price[4000+i], '    ', np.around(np.power(10, linreg3.fittedvalues[4000+i]), decimals = 2), '     ', np.around(np.power(10, linreg4.fittedvalues[4000+i]), decimals = 2), '    ',np.around(np.power(10,linreg3.fittedvalues[4000+i])-np.power(10,linreg4.fittedvalues[4000+i]), decimals = 2)
# Out:
# Date        Sale price  Pred. with list p    W/o list p     W - W/o diff
# 2016-08-16      917500      1025959.83       1193233.28      -167273.44
# 2016-08-16      850000      834018.92       680554.19      153464.73
# 2016-08-16      670000      653762.02       626866.74      26895.29
# 2016-08-16      980000      1040460.76       1322391.78      -281931.02
# 2016-08-16      9750000      9770958.09       6157536.68      3613421.42
# 2016-08-17      1100000      1065411.54       1314364.55      -248953.01
# 2016-08-17      1050000      1136881.33       932981.43      203899.9
# 2016-08-17      775000      806083.35       638109.24      167974.12
# 2016-08-17      699000      802734.47       1105665.1      -302930.62
# 2016-08-17      385000      366568.29       356501.1      10067.19
# 2016-08-17      790000      726309.25       646598.11      79711.14
# 2016-08-18      755000      726028.55       858409.46      -132380.9
# 2016-08-18      1850000      1846804.93       1827720.88      19084.05
# 2016-08-18      760000      823950.75       963011.33      -139060.59
# 2016-08-18      1475000      1707527.18       1552829.88      154697.3
# 2016-08-19      1450000      1506452.54       1506251.37      201.17
# 2016-08-19      595000      622486.89       526256.19      96230.7
# 2016-08-19      805000      800827.73       762143.41      38684.32
# 2016-08-19      765000      717364.66       679725.12      37639.54
# 2016-08-19      850000      876679.73       744313.73      132366.0
# 2016-08-19      2150000      2265643.68       1833952.08      431691.6
# 2016-08-19      2500000      2503779.98       2066991.84      436788.14
# 2016-08-19      1200000      1328905.56       1477084.41      -148178.86
# 2016-08-19      925000      808930.33       718472.01      90458.32
# 2016-08-19      3091000      3127972.66       2461917.96      666054.7
# 2016-08-19      779000      853464.98       1142121.89      -288656.9
# 2016-08-19      640000      638044.91       996618.11      -358573.2
# 2016-08-19      715000      712549.59       808652.17      -96102.58
# 2016-08-22      1710000      1608333.27       1470861.41      137471.86
# 2016-08-22      1050000      1058795.36       1391882.14      -333086.77

# %%
X_sold.head(3)
# Out:
#             bedroom  bath  parking  sqft  home_own_ass  day_on_market  \
# sold
# 2013-11-12        2   2.0        1  1456        565.00             38
# 2013-11-12        2   1.5        0   744        556.00              8
# 2013-11-12        1   1.0        1   700        511.14             35
#
#             single_f_h  condo  dist_no  sold_year         ...           \
# sold                                                      ...
# 2013-11-12           0      1        8       2013         ...
# 2013-11-12           0      1        8       2013         ...
# 2013-11-12           0      1        8       2013         ...
#
#             North Waterfront    Outer Mission    Pacific Heights    Portola    \
# sold
# 2013-11-12                   0                0                  0          0
# 2013-11-12                   0                0                  0          0
# 2013-11-12                   0                0                  0          0
#
#             Presidio Heights    Russian Hill    Silver Terrace    \
# sold
# 2013-11-12                   0               0                 0
# 2013-11-12                   0               0                 0
# 2013-11-12                   0               0                 0
#
#             Telegraph Hill    Van Ness/Civic Cente    Visitacion Valley
# sold
# 2013-11-12                 0                       0                    0
# 2013-11-12                 0                       0                    0
# 2013-11-12                 0                       0                    0
#
# [3 rows x 35 columns]

# %%
X_sold.columns
# Out:
# Index([               u'bedroom',                   u'bath',
#                       u'parking',                   u'sqft',
#                  u'home_own_ass',          u'day_on_market',
#                    u'single_f_h',                  u'condo',
#                       u'dist_no',              u'sold_year',
#                    u'sold_month',      u'Bayview Heights  ',
#                     u'Bayview  ',    u'Candlestick Point  ',
#                  u'Cow Hollow  ',       u'Crocker Amazon  ',
#                    u'Downtown  ',            u'Excelsior  ',
#          u'Financial District  ',        u'Hunters Point  ',
#            u'Little Hollywood  ',               u'Marina  ',
#             u'Mission Terrace  ',             u'Nob Hill  ',
#                 u'North Beach  ',     u'North Waterfront  ',
#               u'Outer Mission  ',      u'Pacific Heights  ',
#                     u'Portola  ',     u'Presidio Heights  ',
#                u'Russian Hill  ',       u'Silver Terrace  ',
#              u'Telegraph Hill  ', u'Van Ness/Civic Cente  ',
#           u'Visitacion Valley  '],
#       dtype='object')

# %%
y_sold.head()
# Out:
# sold
# 2013-11-12    1130000
# 2013-11-12     595000
# 2013-11-12     610000
# 2013-11-13    3850000
# 2013-11-13     665000
# Name: sale_price, dtype: int64

# %%
y_sold_log = np.log10(y_sold)

lr_log_all= linear_model.LinearRegression(normalize = True)
lr_log_all.fit(X_sold, y_sold_log)
predicted_all_log = cross_val_predict(lr_log_all, X_sold, y_sold_log, cv=10)

fig, ax = plt.subplots(figsize=(25,15))
fig.suptitle('whole set log10 price LinearRegression without list price', fontsize=20)
ax.scatter(y_sold_log, predicted_all_log)
ax.plot([y_sold_log.min(), y_sold_log.max()], [y_sold_log.min(), y_sold_log.max()], 'k--', lw=4)
ax.set_xlabel('Measured', fontsize=20)
ax.set_ylabel('Predicted', fontsize=20)
plt.show()

print('lr_log_all All Variance score: %.2f' % lr_log_all.score(X_sold, y_sold_log))
# Out:
# lr_log_all All Variance score: 0.86

# %%
print np.power(10, y_test_log[0]), np.power(10, y_sold_log[4000])
# Out:
# 917500.0 917500.0

# %%
print 'Date        Square-Foot     Sale-price    Predicted price '
for i in xrange(30):
    print X_test.index[i].date(),'     ', X_test.sqft[i],'     ', np.power(10, y_test_log[i]), '     ', np.power(10, predicted_all_log[4000+i]).round(2)
# Out:
# Date        Square-Foot     Sale-price    Predicted price
# 2016-08-16       700       917500.0       1214198.11
# 2016-08-16       1312       850000.0       690610.85
# 2016-08-16       760       670000.0       636282.39
# 2016-08-16       1050       980000.0       1351824.8
# 2016-08-16       4617       9750000.0       6199524.75
# 2016-08-17       1140       1100000.0       1348978.05
# 2016-08-17       1210       1050000.0       949062.74
# 2016-08-17       1000       775000.0       642211.71
# 2016-08-17       550       699000.0       1129898.81
# 2016-08-17       527       385000.0       362719.01
# 2016-08-17       975       790000.0       654696.53
# 2016-08-18       1290       755000.0       867913.74
# 2016-08-18       1841       1850000.0       1850691.3
# 2016-08-18       460       760000.0       983691.43
# 2016-08-18       1350       1475000.0       1605337.71
# 2016-08-19       1382       1450000.0       1536683.66
# 2016-08-19       825       595000.0       536102.76
# 2016-08-19       1394       805000.0       771379.45
# 2016-08-19       1200       765000.0       689834.83
# 2016-08-19       900       850000.0       744852.56
# 2016-08-19       1710       2150000.0       1871616.21
# 2016-08-19       2224       2500000.0       2089625.02
# 2016-08-19       985       1200000.0       1507379.68
# 2016-08-19       1300       925000.0       720755.7
# 2016-08-19       2076       3091000.0       2516267.66
# 2016-08-19       650       779000.0       1172607.94
# 2016-08-19       534       640000.0       1027639.57
# 2016-08-19       751       715000.0       806748.71
# 2016-08-22       1200       1710000.0       1515664.32
# 2016-08-22       966       1050000.0       1424378.76

# %%
print 'Date        Square-Foot     Sale-price    Predicted price '
for i in xrange(30):
    print X_test.index[i].date(),'     ', X_test.sqft[i],'     ', np.power(10, y_test_log[i]), '     ', np.power(10, predicted_test_log[i]).round(2)
# Out:
# Date        Square-Foot     Sale-price    Predicted price
# 2016-08-16       700       917500.0       1218814.18
# 2016-08-16       1312       850000.0       615265.41
# 2016-08-16       760       670000.0       604296.39
# 2016-08-16       1050       980000.0       1134194.4
# 2016-08-16       4617       9750000.0       5327978.95
# 2016-08-17       1140       1100000.0       1000000.0
# 2016-08-17       1210       1050000.0       835362.55
# 2016-08-17       1000       775000.0       637804.38
# 2016-08-17       550       699000.0       964661.62
# 2016-08-17       527       385000.0       339820.83
# 2016-08-17       975       790000.0       637804.38
# 2016-08-18       1290       755000.0       897687.13
# 2016-08-18       1841       1850000.0       2053525.03
# 2016-08-18       460       760000.0       835362.55
# 2016-08-18       1350       1475000.0       1382372.23
# 2016-08-19       1382       1450000.0       2738419.63
# 2016-08-19       825       595000.0       532797.89
# 2016-08-19       1394       805000.0       791475.54
# 2016-08-19       1200       765000.0       649381.63
# 2016-08-19       900       850000.0       835362.55
# 2016-08-19       1710       2150000.0       1654817.1
# 2016-08-19       2224       2500000.0       3050527.89
# 2016-08-19       985       1200000.0       1357727.14
# 2016-08-19       1300       925000.0       723394.16
# 2016-08-19       2076       3091000.0       2206734.07
# 2016-08-19       650       779000.0       1018151.72
# 2016-08-19       534       640000.0       777365.03
# 2016-08-19       751       715000.0       913981.7
# 2016-08-22       1200       1710000.0       1134194.4
# 2016-08-22       966       1050000.0       1175743.27

# %%
df.head(1)
# Out:
#             address           district  bedroom  bath  parking   sqft  \
# 0  2701 Broadway St  Pacific Heights          7   7.0        2  16400
#
#    dollar_sqft       sold  home_own_ass  day_on_market  list_price  \
# 0  1890.243902 2015-05-15           0.0            100    39000000
#
#    sale_price  sale_to_list_ratio  single_f_h  condo  dist_no  sold_year  \
# 0    31000000           79.487179           1      0        7       2015
#
#    sold_month
# 0           5

# %%
resids = linreg4.outlier_test()['student_resid']

# %%
resids.shape
# Out:
# (4339,)

# %%
fig = plt.figure(figsize=(25,15))
plt.plot(linreg4.fittedvalues, resids, 'o')
plt.xlabel('studentized residuals', fontsize=20)
plt.ylabel('predicted response', fontsize=20)
plt.axhline(0, c='r', linestyle = '--')

# %%
sm.graphics.qqplot(resids, line='45', fit=True)

# %%
sm.graphics.qqplot(resids, line='q', fit=True)

# %%
from statsmodels.graphics import regressionplots as smg

# %%
smg.influence_plot(linreg4)

# %%
df_sold.loc['2014-12-30']
# Out:
#                         address                district  bedroom  bath  \
# sold
# 2014-12-30    666 Post St #1601              Downtown          1   1.0
# 2014-12-30      1037 Vallejo St          Russian Hill          3   2.5
# 2014-12-30    120 Wetmore St #5              Nob Hill          2   2.0
# 2014-12-30      260 Niagara Ave         Outer Mission          2   1.0
# 2014-12-30     2179 Pacific Ave       Pacific Heights          4   2.5
# 2014-12-30          85 Casa Way                Marina          3   3.5
# 2014-12-30        1726 Keith St               Bayview          4   2.0
# 2014-12-30   1388 Gough St #703  Van Ness/Civic Cente          2   2.0
# 2014-12-30  690 Market St #2101    Financial District          2   2.0
# 2014-12-30        577 Sawyer St     Visitacion Valley          4   2.0
#
#             parking  sqft  dollar_sqft  home_own_ass  day_on_market  \
# sold
# 2014-12-30        0   590   889.830508        445.41             32
# 2014-12-30        2  2590  1563.706564       2867.68             80
# 2014-12-30        1  1219   902.378999        568.26             15
# 2014-12-30        3  1125   715.555556          0.00              0
# 2014-12-30        1  2775   906.306306        600.00             87
# 2014-12-30        2  2550   984.313725          0.00              0
# 2014-12-30        1  1495   468.227425          0.00             46
# 2014-12-30        1  1192   868.288591        915.31             29
# 2014-12-30        1  1515  1402.640264      31356.77              0
# 2014-12-30        1  1273   518.460330          0.00             64
#
#             list_price  sale_price  sale_to_list_ratio  single_f_h  condo  \
# sold
# 2014-12-30      525000      525000          100.000000           0      1
# 2014-12-30     4190000     4050000           96.658711           0      1
# 2014-12-30      980000     1100000          112.244898           0      1
# 2014-12-30      749000      805000          107.476636           1      0
# 2014-12-30     2775000     2515000           90.630631           0      1
# 2014-12-30     2500000     2510000          100.400000           1      0
# 2014-12-30      668000      700000          104.790419           1      0
# 2014-12-30      990000     1035000          104.545455           0      1
# 2014-12-30     2195000     2125000           96.810934           0      1
# 2014-12-30      649000      660000          101.694915           1      0
#
#             dist_no  sold_year  sold_month
# sold
# 2014-12-30        8       2014          12
# 2014-12-30        8       2014          12
# 2014-12-30        8       2014          12
# 2014-12-30       10       2014          12
# 2014-12-30        7       2014          12
# 2014-12-30        7       2014          12
# 2014-12-30       10       2014          12
# 2014-12-30        8       2014          12
# 2014-12-30        8       2014          12
# 2014-12-30       10       2014          12

# %%
df_sold.loc['2016-07-14']
# Out:
#                             address            district  bedroom  bath  \
# sold
# 2016-07-14           1422 Palou Ave           Bayview          2   1.0
# 2016-07-14  3800-3810 Washington St  Presidio Heights         14  11.0
# 2016-07-14        1001 Pine St #503          Downtown          1   1.0
#
#             parking   sqft  dollar_sqft  home_own_ass  day_on_market  \
# sold
# 2016-07-14        2   1200   608.333333          0.00             28
# 2016-07-14        5  20516   767.693508          0.00            442
# 2016-07-14        1    650   946.153846        488.15             14
#
#             list_price  sale_price  sale_to_list_ratio  single_f_h  condo  \
# sold
# 2016-07-14      599000      730000          121.869783           1      0
# 2016-07-14    17995000    15750000           87.524312           1      0
# 2016-07-14      595000      615000          103.361345           0      1
#
#             dist_no  sold_year  sold_month
# sold
# 2016-07-14       10       2016           7
# 2016-07-14        7       2016           7
# 2016-07-14        8       2016           7

# %%
X_sold.head()
# Out:
#             bedroom  bath  parking  sqft  home_own_ass  day_on_market  \
# sold
# 2013-11-12        2   2.0        1  1456        565.00             38
# 2013-11-12        1   1.0        1   700        511.14             35
# 2013-11-12        2   1.5        0   744        556.00              8
# 2013-11-13        2   1.5        1  1277          0.00             85
# 2013-11-13        1   1.0        1   605        434.75             22
#
#             list_price  single_f_h  condo  dist_no    ...      \
# sold                                                  ...
# 2013-11-12     1195000           0      1        8    ...
# 2013-11-12      599000           0      1        8    ...
# 2013-11-12      500000           0      1        8    ...
# 2013-11-13     1299888           0      1        7    ...
# 2013-11-13      589000           0      1        8    ...
#
#             Pacific Heights    Portola    Presidio Heights    Russian Hill    \
# sold
# 2013-11-12                  0          0                   0               0
# 2013-11-12                  0          0                   0               0
# 2013-11-12                  0          0                   0               0
# 2013-11-13                  0          0                   0               0
# 2013-11-13                  0          0                   0               0
#
#             Silver Terrace    Telegraph Hill    Van Ness/Civic Cente    \
# sold
# 2013-11-12                 0                 0                       0
# 2013-11-12                 0                 0                       0
# 2013-11-12                 0                 0                       0
# 2013-11-13                 0                 0                       0
# 2013-11-13                 0                 0                       0
#
#             Visitacion Valley    sin_month  cos_month
# sold
# 2013-11-12                    0       -0.5   0.866025
# 2013-11-12                    0       -0.5   0.866025
# 2013-11-12                    0       -0.5   0.866025
# 2013-11-13                    0       -0.5   0.866025
# 2013-11-13                    0       -0.5   0.866025
#
# [5 rows x 37 columns]

# %%
X_sold.columns
# Out:
# Index([               u'bedroom',                   u'bath',
#                       u'parking',                   u'sqft',
#                  u'home_own_ass',          u'day_on_market',
#                    u'list_price',             u'single_f_h',
#                         u'condo',                u'dist_no',
#                     u'sold_year',      u'Bayview Heights  ',
#                     u'Bayview  ',    u'Candlestick Point  ',
#                  u'Cow Hollow  ',       u'Crocker Amazon  ',
#                    u'Downtown  ',            u'Excelsior  ',
#        u'Financial District/B  ',        u'Hunters Point  ',
#            u'Little Hollywood  ',               u'Marina  ',
#             u'Mission Terrace  ',             u'Nob Hill  ',
#                 u'North Beach  ',     u'North Waterfront  ',
#               u'Outer Mission  ',      u'Pacific Heights  ',
#                     u'Portola  ',     u'Presidio Heights  ',
#                u'Russian Hill  ',       u'Silver Terrace  ',
#              u'Telegraph Hill  ', u'Van Ness/Civic Cente  ',
#           u'Visitacion Valley  ',              u'sin_month',
#                     u'cos_month'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sold, y_sold, test_size=0.4, random_state=0)

# %%
X_train.shape
# Out:
# (2604, 37)

# %%
X_test.shape
# Out:
# (1736, 37)

# %%
y_train.shape
# Out:
# (2604,)

# %%
y_test.shape
# Out:
# (1736,)

# %%
lr1 = linear_model.LinearRegression()

# %%
lr1.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lr1.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#clf = svm.SVC(kernel='linear', C=1).fit(X_train, y_train)

# %%
#print clf.score(X_test, y_test)

# %%
#clf[0]

# %%
#type(clf)

# %%
#from sklearn.svm import SVC

# %%
#np.log(df_sold.sale_price)

# %%
print('Coefficients: \n', lr1.coef_)
# Out:
# ('Coefficients: \n', array([ -3.83884834e+03,   7.13008741e+04,   3.11747317e+04,
#          2.35837989e+01,   2.02927010e+01,  -2.38186813e+03,
#          8.34750527e-01,   9.81987962e+04,  -9.81987962e+04,
#         -1.00021982e+05,   1.51510132e+04,   1.16693171e+04,
#         -1.71588632e+04,   8.82084650e+04,  -1.78826785e+04,
#         -2.09880068e+04,  -3.84745289e+04,  -1.99000404e+04,
#         -1.27817884e+04,   7.22996908e+04,   1.27589692e+04,
#         -4.19426975e+04,   1.91653104e+04,   2.72472414e+04,
#         -1.61092956e+04,  -5.60105111e+04,  -3.33650212e+04,
#          1.82750065e+04,  -3.90454205e+04,   9.97636649e+04,
#          1.08446326e+05,  -2.50202272e+04,  -1.66290132e+04,
#         -3.29973821e+04,  -6.95285167e+04,   7.56154807e+03,
#         -7.78807436e+03]))

# %%
print("Mean squared error: %.2f"
      % np.mean((lr1.predict(X_test) - y_test) ** 2))
# Out:
# Mean squared error: 56578297781.02

# %%
np.power(10, np.power(10, 0.76))
# Out:
# 568066.75446238264

# %%
np.power(10, np.power(10, 0.78))
# Out:
# 1060708.0399892735

# %%
np.power(10, np.power(10, 0.78))-np.power(10, np.power(10, 0.76))
# Out:
# 492641.28552689089

# %%
print('Variance score: %.2f' % lr1.score(X_test, y_test))
# Out:
# Variance score: 0.98

# %%
predicted = cross_val_predict(lr1, X_train, y_train, cv=10)

# %%
y_train.shape
# Out:
# (2604,)

# %%
predicted.shape
# Out:
# (2604,)

# %%
y_test.shape
# Out:
# (1736,)

# %%
X_test.head()
# Out:
#             bedroom  bath  parking  sqft  home_own_ass  day_on_market  \
# sold
# 2015-04-02        2   1.0        1  1050          0.00             33
# 2014-07-21        2   2.0        4  1245          0.00             11
# 2014-10-21        1   1.0        1  1115        564.49             11
# 2014-04-01        2   1.0        1   750        194.00             24
# 2015-08-04        3   2.5        1  1980        230.54              0
#
#             list_price  single_f_h  condo  dist_no    ...      \
# sold                                                  ...
# 2015-04-02      699000           1      0       10    ...
# 2014-07-21      249000           1      0       10    ...
# 2014-10-21      995000           0      1        7    ...
# 2014-04-01      139500           0      1       10    ...
# 2015-08-04     1849000           0      1        8    ...
#
#             Pacific Heights    Portola    Presidio Heights    Russian Hill    \
# sold
# 2015-04-02                  0          1                   0               0
# 2014-07-21                  0          0                   0               0
# 2014-10-21                  1          0                   0               0
# 2014-04-01                  0          0                   0               0
# 2015-08-04                  0          0                   0               0
#
#             Silver Terrace    Telegraph Hill    Van Ness/Civic Cente    \
# sold
# 2015-04-02                 0                 0                       0
# 2014-07-21                 0                 0                       0
# 2014-10-21                 0                 0                       0
# 2014-04-01                 0                 0                       0
# 2015-08-04                 0                 0                       0
#
#             Visitacion Valley    sin_month  cos_month
# sold
# 2015-04-02                    0   0.866025  -0.500000
# 2014-07-21                    0  -0.500000  -0.866025
# 2014-10-21                    0  -0.866025   0.500000
# 2014-04-01                    0   0.866025  -0.500000
# 2015-08-04                    0  -0.866025  -0.500000
#
# [5 rows x 37 columns]

# %%
plt.scatter(X_test.list_price, y_test,  color='black')
plt.plot(X_test.list_price, lr1.predict(X_test), color='blue', linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
fig, ax = plt.subplots(figsize=(25,15))
ax.scatter(y_train, predicted)
ax.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c0b7c04e8c21> in <module>()
# ----> 1 y_test.head()
#
# NameError: name 'y_test' is not defined
